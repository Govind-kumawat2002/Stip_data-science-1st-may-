# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kumaw\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Graph
#
# * plot
# *  scallater
# *  hist
# *  bar
# *  pie

# %% [markdown]
# #### Plot

# %%
xpoint =np.array([0,6])
ypoint = np.array([0,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint =np.array([0,6])
ypoint = np.array([0,250])

plt.plot(xpoint,ypoint,'o') # o is used to create scatter plot
plt.show()

# %%
xpoint =np.array([1,8])
plt.plot(xpoint, marker='o')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='o')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='*')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, 'o:b') # o is used to create scatter plot and : is used to create black line
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='o', ms = 30)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='*', ms = 30,mec = 'r')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, marker='*', ms = 30,mec = 'r',mfc = 'g')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, ls = 'dotted')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, ls = 'dashed')
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
plt.plot(xpoint, linewidth = 5)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.xlabel('Arati')
plt.ylabel('Anchal')
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.title('Arati and Anchal dono data science pd rhe hai ')
plt.xlabel('Arati')
plt.ylabel('Anchal')
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
xpoint =np.array([1,8,4 ,5 ])
ypoint =np.array([2,5,8 ,4 ])
plt.title('Arati and Anchal dono data science pd rhe hai ')
plt.xlabel('Arati')
plt.ylabel('Anchal')
plt.grid()
plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
plt.subplot(1,2,1)
plt.plot(x,y)
x = np.array([1,2,3,4,5])
y = np.array([1,8,27,64,125])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
# Scatter plot
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
plt.scatter(x,y)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
plt.scatter(x,y)


x1 = np.array([1,2,3,4,5])
y1 = np.array([1,8,27,64,125])
plt.scatter(x1,y1)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
colour  = np.array(['red','green','blue','yellow','black'])
plt.scatter(x,y,c= colour)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
colour  = np.array(['red','green','blue','yellow','black'])
plt.scatter(x,y,c= colour , alpha= 0.5)
plt.show()

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])
colour  = np.array(['red','green','blue','yellow','black'])
size = np.array([10,20,30,40,50])
plt.scatter(x,y,c= colour , s = size , alpha= 0.5)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,alpha=0.5, s = sizes, c = c )
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y,alpha=0.5, s = sizes, c = c, cmap='coolwarm' ) # camap = color map, viridis, nipy_spectral, coolwarm
plt.colorbar()
plt.show()
# Out:
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_13128\2633006295.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,alpha=0.5, s = sizes, c = c, cmap='coolwarm' ) # camap = color map, viridis, nipy_spectral, coolwarm

# %% [markdown]
# ### Barplot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y)        # bar is used to create bar chart
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)        # bar is used to create bar chart
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y, color = 'green')        # bar is used to create bar chart
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.bar(x,y, color = 'green' , width=0.1)        # bar is used to create bar chart
plt.show()

# %% [markdown]
# #### Hist plot

# %%
x =np.random.normal(170,10,250)
x
# Out:
# array([156.44198702, 185.75716553, 170.21582898, 168.19052466,
#        180.2770053 , 164.81340791, 171.92160368, 138.53534438,
#        164.76627311, 172.39850125, 181.31178808, 171.4332927 ,
#        165.4482927 , 184.14818258, 166.15921989, 188.54001147,
#        179.5914813 , 183.41190498, 164.53859359, 166.27617573,
#        174.06390662, 169.16530523, 175.06513457, 152.31803268,
#        173.64968362, 160.77035757, 163.06951264, 186.78020926,
#        173.71252612, 185.33384291, 188.44880834, 171.10784227,
#        174.94124501, 144.47379132, 162.42810996, 168.21789852,
#        186.07237841, 173.11489178, 177.40177185, 166.85757972,
#        151.25433014, 182.8848278 , 176.59924129, 166.86795598,
#        173.53111195, 180.65747765, 182.94574406, 166.6040623 ,
#        166.2936962 , 180.76491008, 171.23754122, 158.6953134 ,
#        179.3091579 , 170.91581274, 156.95649288, 175.75675948,
#        180.97889244, 182.38111519, 159.98687661, 164.87480709,
#        165.99850393, 187.18829841, 198.4039082 , 168.1312152 ,
#        178.39332512, 156.11175827, 187.61565929, 188.21314669,
#        163.28075075, 159.47587744, 176.76447645, 170.05976861,
#        209.66326785, 166.14469511, 188.40519946, 155.78397983,
#        180.31722098, 164.3927748 , 164.22627527, 173.07181125,
#        175.46658847, 184.43550954, 169.73038756, 164.06001038,
#        184.79790275, 169.08720559, 156.66021937, 179.58770928,
#        185.17463653, 167.34235272, 177.43645916, 153.19161191,
#        179.71261754, 168.84986559, 181.64948146, 175.84641029,
#        173.69181865, 169.30894716, 172.81459958, 175.31934916,
#        187.774101  , 166.10083072, 161.42271727, 163.7271356 ,
#        186.25057024, 175.12072527, 162.5635613 , 147.08244305,
#        160.96866345, 152.83073248, 186.23225829, 173.85138003,
#        186.85196013, 176.05555675, 166.79913018, 155.61173028,
#        158.48520574, 147.5423863 , 141.62479318, 159.12030254,
#        171.27861729, 166.82731243, 179.3910558 , 166.71051025,
#        153.82159588, 181.04868049, 162.81921697, 170.21066849,
#        171.45522451, 168.7160707 , 148.84357014, 164.01331477,
#        188.02411314, 175.44753876, 154.78083686, 162.49488225,
#        172.30214108, 179.48540302, 174.61790583, 151.64983669,
#        179.69453982, 182.32337411, 161.96329886, 173.9687826 ,
#        184.41407774, 159.17792523, 167.59313756, 158.47654706,
#        174.65858365, 189.70239981, 157.76799921, 166.62604122,
#        168.73895624, 159.153075  , 175.98678406, 193.61814814,
#        158.71419654, 163.2787013 , 161.8321698 , 171.62223964,
#        152.6104294 , 179.22267436, 164.9956293 , 177.33008076,
#        179.98072001, 176.78707557, 167.23491595, 167.81004888,
#        154.98078313, 176.28353036, 184.27391363, 168.81797572,
#        172.58005365, 159.15586054, 161.87646891, 188.09949414,
#        175.15465763, 162.29021437, 160.95719986, 158.95356054,
#        166.64436491, 158.8196186 , 160.17876005, 160.82293255,
#        149.12584426, 150.92695889, 175.00906733, 158.71844685,
#        184.9715323 , 169.41016594, 169.57242809, 169.41041603,
#        177.67402882, 170.62090195, 171.87133015, 161.00277211,
#        170.33928809, 176.69484949, 154.2785933 , 177.33742583,
#        165.45693202, 161.3695189 , 162.89918476, 169.37458099,
#        180.33810269, 155.94214827, 153.30729197, 160.12549115,
#        144.53347376, 177.53614206, 179.82693856, 169.03994221,
#        183.02482659, 182.48379252, 165.05945001, 161.4177289 ,
#        176.64946642, 165.32349147, 170.10032578, 172.84564047,
#        163.4409262 , 184.61575083, 176.04989106, 169.40364102,
#        148.96953694, 167.77141382, 154.85742317, 173.70350366,
#        175.011669  , 180.39685528, 156.27420371, 175.18854466,
#        171.50767806, 164.04361584, 168.21053725, 185.89802514,
#        171.28606324, 160.74932141, 154.94227605, 162.79014178,
#        183.38476011, 162.35173407, 164.47095766, 171.72416887,
#        167.56277656, 172.34235079, 165.22769315, 165.6038364 ,
#        177.77698513, 172.57483439])

# %%
plt.hist(x)
# Out:
# (array([ 4., 10., 30., 59., 59., 49., 32.,  5.,  1.,  1.]),
#  array([138.53534438, 145.64813673, 152.76092908, 159.87372142,
#         166.98651377, 174.09930612, 181.21209846, 188.32489081,
#         195.43768315, 202.5504755 , 209.66326785]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Pie

# %%
x = np.array([1,2,3,4])
plt.pie(x)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
plt.pie(x, labels = mylabels, startangle=90)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
colour = ['red','green','blue','yellow']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True, colors=colour)  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
colour = ['red','green','blue','yellow']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True, colors=colour, autopct='%1.1f%%')  
plt.show()

# %%
x = np.array([1,2,3,4])
mylabels = ['apples','bananas','cherries','dates']
colour = ['red','green','blue','yellow']
myexplode = [0.2,0,0,0]
plt.pie(x, labels = mylabels, startangle=90, explode=myexplode, shadow=True, colors=colour, autopct='%1.1f%%')  
plt.legend(title = 'My pie chart')
plt.show()
